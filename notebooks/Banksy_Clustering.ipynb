# %%
library(Banksy)
library(Seurat)
library(SeuratWrappers)

library(ggplot2)
library(gridExtra)

# %%
testData <- Load10X_Spatial(
  data.dir = "/group/jshandl-g00/Spatial-MetScore/Spatial-MetScore/data/raw/Samples/PT-1A/",
  filename = "filtered_feature_bc_matrix.h5"
)
# Out:
# Error in `Load10X_Spatial()`:
#
# ! argument "data.dir" is missing, with no default
#
#     ▆
#
#  1. └─Seurat::Load10X_Spatial() at tmp/ark-debug-103634/564490764.r:1:1
